# %%
import os
import pandas as pd
from IPython.display import display

# Configurar el formato de los números flotantes con comas y dos decimales
pd.options.display.float_format = '{:,.2f}'.format

# 1. Cambiar al directorio de preferencia
carpeta_descargas = os.path.join('C:\\', 'Users', 'patri', 'Downloads')
os.chdir(carpeta_descargas)

# 2. Definir la ruta y leer el archivo CSV
ruta_archivo = os.path.join(carpeta_descargas, 'Height of Male and Female by Country 2022.csv')
df = pd.read_csv(ruta_archivo, encoding='latin1', dtype={'ITEM_CODE': str})

# 3. Imprimir las primeras 50 líneas
print("--- Primeras 50 líneas del dataset ---")
display(df.head(50))

# 4. Calcular la media, mínima y máxima altura de hombres y mujeres
print("\n--- Estadísticas de altura para hombres (cm) ---")
print(f"Media: {df['Male Height in Cm'].mean():,.2f}")
print(f"Mínima: {df['Male Height in Cm'].min():,.2f}")
print(f"Máxima: {df['Male Height in Cm'].max():,.2f}")

print("\n--- Estadísticas de altura para mujeres (cm) ---")
print(f"Media: {df['Female Height in Cm'].mean():,.2f}")
print(f"Mínima: {df['Female Height in Cm'].min():,.2f}")
print(f"Máxima: {df['Female Height in Cm'].max():,.2f}")

# 5. Obtener la data de alturas del país de origen
print("\n--- Datos de altura para México ---")
data_mexico = df[df['Country Name'] == 'Mexico']
display(data_mexico)
# Out:
# --- Primeras 50 líneas del dataset ---
#     Rank                      Country Name  Male Height in Cm  \
# 0      1                       Netherlands             183.78
# 1      2                        Montenegro             183.30
# 2      3                           Estonia             182.79
# 3      4            Bosnia and Herzegovina             182.47
# 4      5                           Iceland             182.10
# 5      6                           Denmark             181.89
# 6      7                    Czech Republic             181.19
# 7      8                            Latvia             181.17
# 8      9                          Slovakia             181.02
# 9     10                          Slovenia             180.98
# 10    11                           Ukraine             180.98
# 11    12                           Croatia             180.76
# 12    13                            Serbia             180.74
# ...
